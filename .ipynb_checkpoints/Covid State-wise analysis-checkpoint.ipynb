# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression as lr
# %matplotlib inline

# %%
df = pd.read_csv(r'/Users/shivambadkas/Downloads/Covid-19 India Status.csv')

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman And Nicobar        10033       0        9904
# 1                             Andhra Pradesh      2319578     119     2304729
# 2                          Arunachal Pradesh        64486       2       64188
# 3                                      Assam       724196    1348      716209
# 4                                      Bihar       830477      17      818204
# 5                                 Chandigarh        91929      18       90746
# 6                               Chhattisgarh      1152170      88     1138048
# 7   Dadra And Nagar Haveli And Daman And Diu        11441       0       11437
# 8                                      Delhi      1865382     468     1838760
# 9                                        Goa       245325      41      241452
# 10                                   Gujarat      1223941      67     1212932
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                  Total Cases    Active  Discharged    Deaths  Active Ratio  \
# Total Cases         1.000000  0.688081    0.999987  0.942269     -0.060715
# Active              0.688081  1.000000    0.689796  0.524145      0.361100
# Discharged          0.999987  0.689796    1.000000  0.940573     -0.060588
# Deaths              0.942269  0.524145    0.940573  1.000000     -0.074942
# Active Ratio       -0.060715  0.361100   -0.060588 -0.074942      1.000000
# Discharge Ratio    -0.115051  0.009883   -0.112836 -0.254047      0.061508
# Death Ratio         0.123493 -0.062131    0.121314  0.261027     -0.210106
# Population         -0.065759 -0.029680   -0.064881 -0.119221     -0.166879
#
#                  Discharge Ratio  Death Ratio  Population
# Total Cases            -0.115051     0.123493   -0.065759
# Active                  0.009883    -0.062131   -0.029680
# Discharged             -0.112836     0.121314   -0.064881
# Deaths                 -0.254047     0.261027   -0.119221
# ...

# %%
import matplotlib as mpt

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman And Nicobar        10033       0        9904
# 1                             Andhra Pradesh      2319578     119     2304729
# 2                          Arunachal Pradesh        64486       2       64188
# 3                                      Assam       724196    1348      716209
# 4                                      Bihar       830477      17      818204
# 5                                 Chandigarh        91929      18       90746
# 6                               Chhattisgarh      1152170      88     1138048
# 7   Dadra And Nagar Haveli And Daman And Diu        11441       0       11437
# 8                                      Delhi      1865382     468     1838760
# 9                                        Goa       245325      41      241452
# 10                                   Gujarat      1223941      67     1212932
# ...

# %%
sns.displot(x = "State/UTs", y = 'Population', hue = 'Active', data = df)

# %%
sns.pairplot(data = df, hue = "State/UTs", height = 3.5)

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman And Nicobar        10033       0        9904
# 1                             Andhra Pradesh      2319578     119     2304729
# 2                          Arunachal Pradesh        64486       2       64188
# 3                                      Assam       724196    1348      716209
# 4                                      Bihar       830477      17      818204
# 5                                 Chandigarh        91929      18       90746
# 6                               Chhattisgarh      1152170      88     1138048
# 7   Dadra And Nagar Haveli And Daman And Diu        11441       0       11437
# 8                                      Delhi      1865382     468     1838760
# 9                                        Goa       245325      41      241452
# 10                                   Gujarat      1223941      67     1212932
# ...

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman And Nicobar        10033       0        9904     129          0.00
# 1       Andhra Pradesh      2319578     119     2304729   14730          0.01
# 2    Arunachal Pradesh        64486       2       64188     296          0.00
# 3                Assam       724196    1348      716209    6639          0.19
# 4                Bihar       830477      17      818204   12256          0.00
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.71         1.29   100896618
# 1            99.36         0.64   128500364
# 2            99.54         0.46      658019
# 3            98.90         0.92      290492
# 4            98.52         1.48    40100376

# %%
# make copy of dataset 
main_df = df.copy()

# %%
df.shape
# Out:
# (36, 9)

# %%
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio', 'Discharge Ratio', 'Death Ratio', 'Population'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# dtype: bool

# %%
df = df.replace('Dadra And Nagar Haveli And Daman And Diu', 'Daman & Diu')
df.head(8)
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman And Nicobar        10033       0        9904     129          0.00
# 1       Andhra Pradesh      2319578     119     2304729   14730          0.01
# 2    Arunachal Pradesh        64486       2       64188     296          0.00
# 3                Assam       724196    1348      716209    6639          0.19
# 4                Bihar       830477      17      818204   12256          0.00
# 5           Chandigarh        91929      18       90746    1165          0.02
# 6         Chhattisgarh      1152170      88     1138048   14034          0.01
# 7          Daman & Diu        11441       0       11437       4          0.00
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.71         1.29   100896618
# 1            99.36         0.64   128500364
# 2            99.54         0.46      658019
# 3            98.90         0.92      290492
# ...

# %%
df.describe()
# Out:
#         Total Cases       Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000     36.000000
# mean   1.195273e+06   334.833333  1.180455e+06   14483.777778      0.035278
# std    1.768290e+06   638.387589  1.742546e+06   26878.151852      0.074622
# min    1.003300e+04     0.000000  9.904000e+03       4.000000      0.000000
# 25%    9.910025e+04    11.500000  9.800600e+04    1104.000000      0.010000
# 50%    5.890055e+05    91.000000  5.825560e+05    5977.000000      0.015000
# 75%    1.284217e+06   317.000000  1.274600e+06   14208.000000      0.030000
# max    7.874446e+06  3339.000000  7.725791e+06  147789.000000      0.420000
#
#        Discharge Ratio  Death Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         98.840833     1.124722  3.971861e+07
# std           0.483312     0.493115  5.050913e+07
# min          97.650000     0.030000  6.600100e+04
# ...

# %%
#check for null value
df.isnull().sum()
# Out:
# State/UTs          0
# Total Cases        0
# Active             0
# Discharged         0
# Deaths             0
# Active Ratio       0
# Discharge Ratio    0
# Death Ratio        0
# Population         0
# dtype: int64

# %%
df.corr()
# Out:
#                  Total Cases    Active  Discharged    Deaths  Active Ratio  \
# Total Cases         1.000000  0.688081    0.999987  0.942269     -0.060715
# Active              0.688081  1.000000    0.689796  0.524145      0.361100
# Discharged          0.999987  0.689796    1.000000  0.940573     -0.060588
# Deaths              0.942269  0.524145    0.940573  1.000000     -0.074942
# Active Ratio       -0.060715  0.361100   -0.060588 -0.074942      1.000000
# Discharge Ratio    -0.115051  0.009883   -0.112836 -0.254047      0.061508
# Death Ratio         0.123493 -0.062131    0.121314  0.261027     -0.210106
# Population         -0.065759 -0.029680   -0.064881 -0.119221     -0.166879
#
#                  Discharge Ratio  Death Ratio  Population
# Total Cases            -0.115051     0.123493   -0.065759
# Active                  0.009883    -0.062131   -0.029680
# Discharged             -0.112836     0.121314   -0.064881
# Deaths                 -0.254047     0.261027   -0.119221
# ...

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10, 10))
sns.barplot(data = df, x = "Death Ratio", y = "State/UTs")
# Out:
# <AxesSubplot:xlabel='Death Ratio', ylabel='State/UTs'>

# %%
px.bar(df, x = "State/UTs", y = 'Total Cases', color = 'Death Ratio', title = "Cases per state")
# Out:
# <div>                            <div id="912728a4-f199-4fd7-abc9-0ec16b12b2c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("912728a4-f199-4fd7-abc9-0ec16b12b2c7")) {                    Plotly.newPlot(                        "912728a4-f199-4fd7-abc9-0ec16b12b2c7",                        [{"alignmentgroup":"True","hovertemplate":"State/UTs=%{x}<br>Total Cases=%{y}<br>Death Ratio=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[1.29,0.64,0.46,0.92,1.48,1.27,1.22,0.03,1.4,1.56,0.89,1.08,1.45,1.05,1.22,1.02,1.04,0.81,0.46,1.03,1.88,1.55,1.7,0.31,2.14,0.71,1.18,2.34,0.74,1.15,1.1,0.52,0.91,1.13,1.76,1.05],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"a
# ...

# %%
fig = px.choropleth(
    df,
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locations='State/UTs',
    color='Deaths',
    color_continuous_scale= 'reds'
)

fig.update_geos(fitbounds="locations", visible=False)

fig.show()
# Out:
# <div>                            <div id="35a2e296-af02-414a-a940-1216d42df6b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35a2e296-af02-414a-a940-1216d42df6b9")) {                    Plotly.newPlot(                        "35a2e296-af02-414a-a940-1216d42df6b9",                        [{"coloraxis":"coloraxis","featureidkey":"properties.ST_NM","geo":"geo","geojson":"https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson","hovertemplate":"State/UTs=%{location}<br>Deaths=%{z}<extra></extra>","locations":["Andaman And Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Daman & Diu","Delhi","Goa","Gujarat","Haryana","Himacha
# ...

# %%
figure = px.scatter(df, x = "Total Cases", y = "Active", size = "Deaths", color = "State/UTs", log_x = True, size_max = 50)
figure.show()
# Out:
# <div>                            <div id="ddd11178-9943-4b8d-9661-ae1e66665114" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddd11178-9943-4b8d-9661-ae1e66665114")) {                    Plotly.newPlot(                        "ddd11178-9943-4b8d-9661-ae1e66665114",                        [{"hovertemplate":"State/UTs=Andaman And Nicobar<br>Total Cases=%{x}<br>Active=%{y}<br>Deaths=%{marker.size}<extra></extra>","legendgroup":"Andaman And Nicobar","marker":{"color":"#636efa","size":[129],"sizemode":"area","sizeref":59.1156,"symbol":"circle"},"mode":"markers","name":"Andaman And Nicobar","orientation":"v","showlegend":true,"x":[10033],"xaxis":"x","y":[0],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UTs=Andhra Pradesh<br>Total Cases=%{x}<br>A
# ...

# %%
fig = px.pie(df, values='Total Cases', names=df['State/UTs'], title='Covid cases (%) in States/UTs')
fig.show()
# Out:
# <div>                            <div id="49b44374-c7c8-4f41-b253-4075b4383dae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49b44374-c7c8-4f41-b253-4075b4383dae")) {                    Plotly.newPlot(                        "49b44374-c7c8-4f41-b253-4075b4383dae",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"State/UTs=%{label}<br>Total Cases=%{value}<extra></extra>","labels":["Andaman And Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Daman & Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu And Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry"
# ...

# %%
df2 = pd.read_csv(r'/Users/shivambadkas/Downloads/GOI.csv')

# %%
df2
# Out:
#            Category Country/ States/ Union Territories Name  \
# 0           Country                                   INDIA
# 1             State                          Andhra Pradesh
# 2             State                       Arunachal Pradesh
# 3             State                                   Assam
# 4             State                                   Bihar
# 5             State                            Chhattisgarh
# 6             State                                     Goa
# 7             State                                 Gujarat
# 8             State                                 Haryana
# 9             State                        Himachal Pradesh
# 10            State                         Jammu & Kashmir
# 11            State                               Jharkhand
# 12            State                               Karnataka
# 13            State                                  Kerala
# 14            State                          Madhya Pradesh
# ...

# %%
df
# Out:
#               State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0   Andaman And Nicobar        10033       0        9904     129
# 1        Andhra Pradesh      2319578     119     2304729   14730
# 2     Arunachal Pradesh        64486       2       64188     296
# 3                 Assam       724196    1348      716209    6639
# 4                 Bihar       830477      17      818204   12256
# 5            Chandigarh        91929      18       90746    1165
# 6          Chhattisgarh      1152170      88     1138048   14034
# 7           Daman & Diu        11441       0       11437       4
# 8                 Delhi      1865382     468     1838760   26154
# 9                   Goa       245325      41      241452    3832
# 10              Gujarat      1223941      67     1212932   10942
# 11              Haryana       985410     265      974528   10617
# 12     Himachal Pradesh       284578      91      280354    4133
# ...

# %%
df2 = df2.replace("NCT of Delhi", "Delhi")
df = df.replace("Dadra And Nagar Haveli And Daman And Diu", "Daman and Diu")
df2 = df2.replace("A & N Islands","Andaman and Nicobar")

# %%
df2
# Out:
#            Category Country/ States/ Union Territories Name  \
# 0           Country                                   INDIA
# 1             State                          Andhra Pradesh
# 2             State                       Arunachal Pradesh
# 3             State                                   Assam
# 4             State                                   Bihar
# 5             State                            Chhattisgarh
# 6             State                                     Goa
# 7             State                                 Gujarat
# 8             State                                 Haryana
# 9             State                        Himachal Pradesh
# 10            State                         Jammu & Kashmir
# 11            State                               Jharkhand
# 12            State                               Karnataka
# 13            State                                  Kerala
# 14            State                          Madhya Pradesh
# ...

# %%
df2 = pd.DataFrame(df2)
df = pd.DataFrame(df)

# %%
df2 = df2.rename(columns = {'Country/ States/ Union Territories Name': 'State/UTs' })

# %%
df2 = df2.drop([0])
df3 = pd.merge(df,df2, on = 'State/UTs')

# %%
df3
# Out:
#             State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0      Andhra Pradesh      2319578     119     2304729   14730          0.01
# 1   Arunachal Pradesh        64486       2       64188     296          0.00
# 2               Assam       724196    1348      716209    6639          0.19
# 3               Bihar       830477      17      818204   12256          0.00
# 4          Chandigarh        91929      18       90746    1165          0.02
# 5        Chhattisgarh      1152170      88     1138048   14034          0.01
# 6         Daman & Diu        11441       0       11437       4          0.00
# 7               Delhi      1865382     468     1838760   26154          0.03
# 8                 Goa       245325      41      241452    3832          0.02
# 9             Gujarat      1223941      67     1212932   10942          0.01
# 10            Haryana       985410     265      974528   10617          0.03
# ...

# %%
df3.plot(kind='scatter', x = 'Literacy Rate (Persons) - Total - 2011', y = 'Death Ratio')
# Out:
# <AxesSubplot:xlabel='Literacy Rate (Persons) - Total - 2011', ylabel='Death Ratio'>

# %%
df3
# Out:
#             State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0      Andhra Pradesh      2319578     119     2304729   14730          0.01
# 1   Arunachal Pradesh        64486       2       64188     296          0.00
# 2               Assam       724196    1348      716209    6639          0.19
# 3               Bihar       830477      17      818204   12256          0.00
# 4          Chandigarh        91929      18       90746    1165          0.02
# 5        Chhattisgarh      1152170      88     1138048   14034          0.01
# 6         Daman & Diu        11441       0       11437       4          0.00
# 7               Delhi      1865382     468     1838760   26154          0.03
# 8                 Goa       245325      41      241452    3832          0.02
# 9             Gujarat      1223941      67     1212932   10942          0.01
# 10            Haryana       985410     265      974528   10617          0.03
# ...

# %%
plt.figure(figsize=(10, 10))
sns.barplot(data = df3, x = "Death Ratio", y = "State/UTs")
# Out:
# <AxesSubplot:xlabel='Death Ratio', ylabel='State/UTs'>

# %%
from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
print(df3.columns)
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio', 'Discharge Ratio', 'Death Ratio', 'Population',
#        'Category', 'Literacy Rate (Persons) - Total - 2001',
#        'Literacy Rate (Persons) - Total - 2011',
#        'Literacy Rate (Persons) - Rural - 2001',
#        'Literacy Rate (Persons) - Rural - 2011',
#        'Literacy Rate (Persons) - Urban - 2001',
#        'Literacy Rate (Persons) - Urban - 2011'],
#       dtype='object')

# %%
new = df3.filter(['State/UTs','Deaths' ,'Total Cases','Death Ratio','Literacy Rate (Persons) - Total - 2011'], axis=1)

# %%
new
# Out:
#             State/UTs  Deaths  Total Cases  Death Ratio  \
# 0      Andhra Pradesh   14730      2319578         0.64
# 1   Arunachal Pradesh     296        64486         0.46
# 2               Assam    6639       724196         0.92
# 3               Bihar   12256       830477         1.48
# 4          Chandigarh    1165        91929         1.27
# 5        Chhattisgarh   14034      1152170         1.22
# 6         Daman & Diu       4        11441         0.03
# 7               Delhi   26154      1865382         1.40
# 8                 Goa    3832       245325         1.56
# 9             Gujarat   10942      1223941         0.89
# 10            Haryana   10617       985410         1.08
# 11   Himachal Pradesh    4133       284578         1.45
# 12          Jharkhand    5315       435153         1.22
# 13          Karnataka   40055      3945698         1.02
# 14             Kerala   68130      6533998         1.04
# 15        Lakshadweep      52        11402         0.46
# ...

# %%
print(new.corr())
# Out:
#                                           Deaths  Total Cases  Death Ratio  \
# Deaths                                  1.000000     0.941365     0.249698
# Total Cases                             0.941365     1.000000     0.110414
# Death Ratio                             0.249698     0.110414     1.000000
# Literacy Rate (Persons) - Total - 2011  0.115925     0.091458    -0.056831
#
#                                         Literacy Rate (Persons) - Total - 2011
# Deaths                                                                0.115925
# Total Cases                                                           0.091458
# Death Ratio                                                          -0.056831
# Literacy Rate (Persons) - Total - 2011                                1.000000

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
X= new['Literacy Rate (Persons) - Total - 2011'].values.reshape((-1, 1))
y= new['Death Ratio'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 1.6020560393991812
# [-0.00534443]
